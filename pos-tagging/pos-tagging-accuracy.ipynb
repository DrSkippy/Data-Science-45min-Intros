# %% [markdown]
# # Outline
#
# * Collect some tweets
# * Annotate the tweets
# * Calculate the accuracy

# %%
from pprint import pprint

# %% [markdown]
# # Collect some data

# %%
# we'll use data from an HPT job that collected tweets about parenting
tweet_bodies = [body for body in open('tweet_bodies.txt')]

# %%
# sanity checks
pprint(len(tweet_bodies))
# Out:
# 103

# %%
# sanity checks
pprint(tweet_bodies[:10])
# Out:
# ['&gt;&gt;&gt;&gt;&gt;NOTHING THE LIBERAL PARTY HAS PRODUCED HAS CREDIBILITY '
#  "IN IT, &amp; THEY'RE NOT GOING TO START NOW!!! https://t.co/oH5YfQcFCl\n",
#  "Thank y'all @RRExpress 4 hosting our kids workshop,gave out abt 600 kits and "
#  'had a ton of fun!!@jermeybotkin @Blair88833704 @sm6574 @bjp84\n',
#  'About Trump digest (2/7): I started creating Trump digest playlists in early '
#  "2016 to teach my kids about Trump, even though most can't vote\n",
#  'And now a fantastic electric storm overhead.  The original and best son et '
#  'lumiere. Other guests all dining indoors. They must be mad!\n',
#  'Why Young Kids Learn Through Movement ----&gt;https://t.co/YyF7HAL04u via '
#  '@TheAtlantic https://t.co/RiFHdl2ipy\n',
#  'Love this story by @wrivey about a creative way of leaving notes for your '
#  'kids. https://t.co/ZlmnLgQm0R\n',
#  'Love this story by @wrivey about a creative way of leaving notes for your '
#  'kids. https://t.co/nSBM2rejh0\n',
#  'Love this story by @wrivey about a creative way of leaving notes for your '
#  'kids. https://t.co/TrrumJzi8N\n',
#  'Love this story by @wrivey about a creative way of leaving notes for your '
#  'kids. https://t.co/mqsRt6yva3\n',
#  'Love this story by @wrivey about a creative way of leaving notes for your '
#  'kids. https://t.co/hNtkuDwL4d\n']

# %%
# lets do some quick deduplication
from duplicate_filter import duplicateFilter

## set the similarity threshold at 90%
dup_filter = duplicateFilter(0.9)

deduped_tweet_bodies = []
for id,tweet_body in enumerate(tweet_bodies):
    if not dup_filter.isDup(id,tweet_body):
        deduped_tweet_bodies.append(tweet_body)

pprint(deduped_tweet_bodies[:10])
# Out:
# ['&gt;&gt;&gt;&gt;&gt;NOTHING THE LIBERAL PARTY HAS PRODUCED HAS CREDIBILITY '
#  "IN IT, &amp; THEY'RE NOT GOING TO START NOW!!! https://t.co/oH5YfQcFCl\n",
#  "Thank y'all @RRExpress 4 hosting our kids workshop,gave out abt 600 kits and "
#  'had a ton of fun!!@jermeybotkin @Blair88833704 @sm6574 @bjp84\n',
#  'About Trump digest (2/7): I started creating Trump digest playlists in early '
#  "2016 to teach my kids about Trump, even though most can't vote\n",
#  'And now a fantastic electric storm overhead.  The original and best son et '
#  'lumiere. Other guests all dining indoors. They must be mad!\n',
#  'Why Young Kids Learn Through Movement ----&gt;https://t.co/YyF7HAL04u via '
#  '@TheAtlantic https://t.co/RiFHdl2ipy\n',
#  'Love this story by @wrivey about a creative way of leaving notes for your '
#  'kids. https://t.co/ZlmnLgQm0R\n',
#  'I love my kids, Man. These are just 3 out of 8. They all grown up now. '
#  '#lippoldislegend… https://t.co/Z0IM0ITgRX\n',
#  "Now through 8/31, you can be the change in a child's life with "
#  '@vitaminangels. Learn more: https://t.co/nhWvtfAQGY '
#  'https://t.co/pEXvX8041u\n',
#  "#Baby Education provides a learning environment that stimulates the child's "
#  'interest in learning and maximizes https://t.co/Sj2d9Wfi4a\n',
#  'Some people love growing up, they have always wanted to be older. I have '
#  'always wanted to be a kid for life\n']

# %% [markdown]
# # Annotate the data
#
# ## Start by tokenizing

# %%
from nltk.tokenize import TweetTokenizer
tt = TweetTokenizer()
tokenized_deduped_tweet_bodies = [tt.tokenize(body) for body in deduped_tweet_bodies]

# %%
# sanity checks
len(tokenized_deduped_tweet_bodies)
# Out:
# 98

# %%
pprint(tokenized_deduped_tweet_bodies[:2])
# Out:
# [['>',
#   '>',
#   '>',
#   'NOTHING',
#   'THE',
#   'LIBERAL',
#   'PARTY',
#   'HAS',
#   'PRODUCED',
#   'HAS',
#   'CREDIBILITY',
#   'IN',
#   'IT',
#   ',',
#   '&',
#   "THEY'RE",
#   'NOT',
#   'GOING',
#   'TO',
#   'START',
#   'NOW',
#   '!',
#   '!',
#   '!',
#   'https://t.co/oH5YfQcFCl'],
#  ['Thank',
#   "y'all",
#   '@RRExpress',
#   '4',
#   'hosting',
#   'our',
#   'kids',
#   'workshop',
#   ',',
#   'gave',
#   'out',
#   'abt',
#   '600',
#   'kits',
#   'and',
#   'had',
#   'a',
#   'ton',
#   'of',
#   'fun',
#   '!',
#   '!',
#   '@jermeybotkin',
#   '@Blair88833704',
#   '@sm6574',
#   '@bjp84']]

# %% [markdown]
# ## Now tag the tokens with parts-of-speech labels
#
# The default configuration is the Greedy Averaged Perceptron tagger (https://explosion.ai/blog/part-of-speech-pos-tagger-in-python)

# %%
from nltk.tag import pos_tag as pos_tagger
tagged_tokenized_deduped_tweet_bodies = [ pos_tagger(tokens) for tokens in tokenized_deduped_tweet_bodies]

# %%
pprint(tagged_tokenized_deduped_tweet_bodies[:2])
# Out:
# [[('>', 'JJ'),
#   ('>', 'NNP'),
#   ('>', 'NNP'),
#   ('NOTHING', 'NNP'),
#   ('THE', 'NNP'),
#   ('LIBERAL', 'NNP'),
#   ('PARTY', 'NNP'),
#   ('HAS', 'NNP'),
#   ('PRODUCED', 'NNP'),
#   ('HAS', 'NNP'),
#   ('CREDIBILITY', 'NNP'),
#   ('IN', 'NNP'),
#   ('IT', 'NNP'),
#   (',', ','),
#   ('&', 'CC'),
#   ("THEY'RE", 'NNP'),
#   ('NOT', 'NNP'),
#   ('GOING', 'NNP'),
#   ('TO', 'NNP'),
#   ('START', 'NNP'),
#   ('NOW', 'NNP'),
#   ('!', '.'),
#   ('!', '.'),
#   ('!', '.'),
#   ('https://t.co/oH5YfQcFCl', 'NN')],
#  [('Thank', 'NNP'),
#   ("y'all", 'NN'),
#   ('@RRExpress', 'NN'),
#   ('4', 'CD'),
#   ('hosting', 'VBG'),
#   ('our', 'PRP$'),
#   ('kids', 'NNS'),
#   ('workshop', 'NN'),
#   (',', ','),
#   ('gave', 'VBD'),
#   ('out', 'RP'),
#   ('abt', 'JJ'),
#   ('600', 'CD'),
#   ('kits', 'NNS'),
#   ('and', 'CC'),
#   ('had', 'VBD'),
#   ('a', 'DT'),
#   ('ton', 'NN'),
#   ('of', 'IN'),
#   ('fun', 'NN'),
#   ('!', '.'),
#   ('!', '.'),
#   ('@jermeybotkin', 'JJ'),
#   ('@Blair88833704', 'NN'),
#   ('@sm6574', 'NNP'),
#   ('@bjp84', 'NN')]]

# %%
# let's look at the taxonomy of tags; in our case derived from the Penn treebank project 
# (http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.9.8216&rep=rep1&type=pdf)

import nltk
nltk.help.upenn_tagset()
# Out:
# $: dollar
#     $ -$ --$ A$ C$ HK$ M$ NZ$ S$ U.S.$ US$
# '': closing quotation mark
#     ' ''
# (: opening parenthesis
#     ( [ {
# ): closing parenthesis
#     ) ] }
# ,: comma
#     ,
# --: dash
#     --
# .: sentence terminator
#     . ! ?
# :: colon or ellipsis
#     : ; ...
# CC: conjunction, coordinating
#     & 'n and both but either et for less minus neither nor or plus so
#     therefore times v. versus vs. whether yet
# CD: numeral, cardinal
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# EX: existential there
#     there
# FW: foreign word
#     gemeinschaft hund ich jeux habeas Haementeria Herr K'ang-si vous
#     lutihaw alai je jour objets salutaris fille quibusdam pas trop Monte
#     terram fiche oui corporis ...
# IN: preposition or conjunction, subordinating
#     astride among uppon whether out inside pro despite on by throughout
#     below within for towards near behind atop around if like until below
#     next into if beside ...
# JJ: adjective or numeral, ordinal
#     third ill-mannered pre-war regrettable oiled calamitous first separable
#     ectoplasmic battery-powered participatory fourth still-to-be-named
#     multilingual multi-disciplinary ...
# JJR: adjective, comparative
#     bleaker braver breezier briefer brighter brisker broader bumper busier
#     calmer cheaper choosier cleaner clearer closer colder commoner costlier
#     cozier creamier crunchier cuter ...
# JJS: adjective, superlative
#     calmest cheapest choicest classiest cleanest clearest closest commonest
#     corniest costliest crassest creepiest crudest cutest darkest deadliest
#     dearest deepest densest dinkiest ...
# LS: list item marker
#     A A. B B. C C. D E F First G H I J K One SP-44001 SP-44002 SP-44005
#     SP-44007 Second Third Three Two * a b c d first five four one six three
#     two
# MD: modal auxiliary
#     can cannot could couldn't dare may might must need ought shall should
#     shouldn't will would
# NN: noun, common, singular or mass
#     common-carrier cabbage knuckle-duster Casino afghan shed thermostat
#     investment slide humour falloff slick wind hyena override subhumanity
#     machinist ...
# NNP: noun, proper, singular
#     Motown Venneboerger Czestochwa Ranzer Conchita Trumplane Christos
#     Oceanside Escobar Kreisler Sawyer Cougar Yvette Ervin ODI Darryl CTCA
#     Shannon A.K.C. Meltex Liverpool ...
# NNPS: noun, proper, plural
#     Americans Americas Amharas Amityvilles Amusements Anarcho-Syndicalists
#     Andalusians Andes Andruses Angels Animals Anthony Antilles Antiques
#     Apache Apaches Apocrypha ...
# NNS: noun, common, plural
#     undergraduates scotches bric-a-brac products bodyguards facets coasts
#     divestitures storehouses designs clubs fragrances averages
#     subjectivists apprehensions muses factory-jobs ...
# PDT: pre-determiner
#     all both half many quite such sure this
# POS: genitive marker
#     ' 's
# PRP: pronoun, personal
#     hers herself him himself hisself it itself me myself one oneself ours
#     ourselves ownself self she thee theirs them themselves they thou thy us
# PRP$: pronoun, possessive
#     her his mine my our ours their thy your
# RB: adverb
#     occasionally unabatingly maddeningly adventurously professedly
#     stirringly prominently technologically magisterially predominately
#     swiftly fiscally pitilessly ...
# RBR: adverb, comparative
#     further gloomier grander graver greater grimmer harder harsher
#     healthier heavier higher however larger later leaner lengthier less-
#     perfectly lesser lonelier longer louder lower more ...
# RBS: adverb, superlative
#     best biggest bluntest earliest farthest first furthest hardest
#     heartiest highest largest least less most nearest second tightest worst
# RP: particle
#     aboard about across along apart around aside at away back before behind
#     by crop down ever fast for forth from go high i.e. in into just later
#     low more off on open out over per pie raising start teeth that through
#     under unto up up-pp upon whole with you
# SYM: symbol
#     % & ' '' ''. ) ). * + ,. < = > @ A[fj] U.S U.S.S.R * ** ***
# TO: "to" as preposition or infinitive marker
#     to
# UH: interjection
#     Goodbye Goody Gosh Wow Jeepers Jee-sus Hubba Hey Kee-reist Oops amen
#     huh howdy uh dammit whammo shucks heck anyways whodunnit honey golly
#     man baby diddle hush sonuvabitch ...
# VB: verb, base form
#     ask assemble assess assign assume atone attention avoid bake balkanize
#     bank begin behold believe bend benefit bevel beware bless boil bomb
#     boost brace break bring broil brush build ...
# VBD: verb, past tense
#     dipped pleaded swiped regummed soaked tidied convened halted registered
#     cushioned exacted snubbed strode aimed adopted belied figgered
#     speculated wore appreciated contemplated ...
# VBG: verb, present participle or gerund
#     telegraphing stirring focusing angering judging stalling lactating
#     hankerin' alleging veering capping approaching traveling besieging
#     encrypting interrupting erasing wincing ...
# VBN: verb, past participle
#     multihulled dilapidated aerosolized chaired languished panelized used
#     experimented flourished imitated reunifed factored condensed sheared
#     unsettled primed dubbed desired ...
# VBP: verb, present tense, not 3rd person singular
#     predominate wrap resort sue twist spill cure lengthen brush terminate
#     appear tend stray glisten obtain comprise detest tease attract
#     emphasize mold postpone sever return wag ...
# VBZ: verb, present tense, 3rd person singular
#     bases reconstructs marks mixes displeases seals carps weaves snatches
#     slumps stretches authorizes smolders pictures emerges stockpiles
#     seduces fizzes uses bolsters slaps speaks pleads ...
# WDT: WH-determiner
#     that what whatever which whichever
# WP: WH-pronoun
#     that what whatever whatsoever which who whom whosoever
# WP$: WH-pronoun, possessive
#     whose
# WRB: Wh-adverb
#     how however whence whenever where whereby whereever wherein whereof why
# ``: opening quotation mark
#     ` ``

# %%
# let's peek at the tag dictionary for our tagger

from nltk.tag.perceptron import PerceptronTagger
t = PerceptronTagger()
pprint(list(t.tagdict.items())[:10])
# Out:
# [('Ortega', 'NNP'),
#  ('Thomson', 'NNP'),
#  ('Canada', 'NNP'),
#  ('exchanges', 'NNS'),
#  ('Prime', 'NNP'),
#  ('natural', 'JJ'),
#  ('went', 'VBD'),
#  ('``', '``'),
#  ('1986', 'CD'),
#  ('night', 'NN')]

# %% [markdown]
# # Evaluate the annotations

# %% [markdown]
# We must choose which parts of speech to evaluate. Let's focus on adjectives, which are useful for sentiment analysis, and proper nouns, which provide a set of potential events and topics.
#
# * JJ: adjective or numeral, ordinal
# * JJR: adjective, comparative
# * JJS: adjective, superlative
#
#
# * NNP: noun, proper, singular
# * NNPS: noun, proper, plural

# %%
adjective_tags = ['JJ','JJR','JJS']
pn_tags = ['NNP','NNPS']
tag_types = [('adj',adjective_tags),('PN',pn_tags)]

# %%
# print format: "POS: TOKEN --> TWEET TEXT"

for body,tweet_tokens,tagged_tokens in zip(deduped_tweet_bodies,tokenized_deduped_tweet_bodies,tagged_tokenized_deduped_tweet_bodies):
    for token,tag in tagged_tokens:
        if tag in adjective_tags:
        #if tag in pn_tags:
            print_str = '{}: {} --> {}'.format(tag,token,body)
            print(print_str)
# Out:
# JJ: > --> &gt;&gt;&gt;&gt;&gt;NOTHING THE LIBERAL PARTY HAS PRODUCED HAS CREDIBILITY IN IT, &amp; THEY'RE NOT GOING TO START NOW!!! https://t.co/oH5YfQcFCl
#
# JJ: abt --> Thank y'all @RRExpress 4 hosting our kids workshop,gave out abt 600 kits and had a ton of fun!!@jermeybotkin @Blair88833704 @sm6574 @bjp84
#
# JJ: @jermeybotkin --> Thank y'all @RRExpress 4 hosting our kids workshop,gave out abt 600 kits and had a ton of fun!!@jermeybotkin @Blair88833704 @sm6574 @bjp84
#
# JJS: digest --> About Trump digest (2/7): I started creating Trump digest playlists in early 2016 to teach my kids about Trump, even though most can't vote
#
# JJ: early --> About Trump digest (2/7): I started creating Trump digest playlists in early 2016 to teach my kids about Trump, even though most can't vote
#
# JJS: most --> About Trump digest (2/7): I started creating Trump digest playlists in early 2016 to teach my kids about Trump, even though most can't vote
#
# JJ: can't --> About Trump digest (2/7): I started creating Trump digest playlists in early 2016 to teach my kids about Trump, even though most can't vote
#
# JJ: fantastic --> And now a fantastic electric storm overhead.  The original and best son et lumiere. Other guests all dining indoors. They must be mad!
#
# JJ: electric --> And now a fantastic electric storm overhead.  The original and best son et lumiere. Other guests all dining indoors. They must be mad!
#
# JJ: original --> And now a fantastic electric storm overhead.  The original and best son et lumiere. Other guests all dining indoors. They must be mad!
#
# JJS: best --> And now a fantastic electric storm overhead.  The original and best son et lumiere. Other guests all dining indoors. They must be mad!
#
# JJ: Other --> And now a fantastic electric storm overhead.  The original and best son et lumiere. Other guests all dining indoors. They must be mad!
#
# JJ: mad --> And now a fantastic electric storm overhead.  The original and best son et lumiere. Other guests all dining indoors. They must be mad!
#
# JJ: @TheAtlantic --> Why Young Kids Learn Through Movement ----&gt;https://t.co/YyF7HAL04u via @TheAtlantic https://t.co/RiFHdl2ipy
#
# JJ: creative --> Love this story by @wrivey about a creative way of leaving notes for your kids. https://t.co/ZlmnLgQm0R
#
# JJ: … --> I love my kids, Man. These are just 3 out of 8. They all grown up now. #lippoldislegend… https://t.co/Z0IM0ITgRX
#
# JJ: evolved --> A nuclearnado? With evolved sharks. I kid you not #Sharknado4
#
# JJ: good --> @JJWatt Oh my!  This is too good.   Love that kid and the bond y'all have developed.
#
# JJ: sad --> sad how kids stay indoors all the time . I know it's hot but fuck, being inside the house all day is depressing
#
# JJ: it's --> sad how kids stay indoors all the time . I know it's hot but fuck, being inside the house all day is depressing
#
# JJ: hot --> sad how kids stay indoors all the time . I know it's hot but fuck, being inside the house all day is depressing
#
# JJ: fuck --> sad how kids stay indoors all the time . I know it's hot but fuck, being inside the house all day is depressing
#
# JJ: such --> @KrisJenner you are such an amazing mom. I pray I could do for my kids, what you have done for yours. You inspire me, and keep me believing♡
#
# JJ: amazing --> @KrisJenner you are such an amazing mom. I pray I could do for my kids, what you have done for yours. You inspire me, and keep me believing♡
#
# JJ: alternative --> Fun fact. there's a alternative ending to the speech, that Subaru and Rem literally do runaway together get married, have kids.
#
# JJ: don't --> Kids grow up so fast, don't forget to stop and look around once in awhile. https://t.co/BH6AcLX09A
#
# JJ: active --> Let your children enjoy the outdoors while staying active with this monkey-bar outdoor play set. This play set has interlocking connecter...
#
# JJ: outdoor --> Let your children enjoy the outdoors while staying active with this monkey-bar outdoor play set. This play set has interlocking connecter...
#
# JJ: @DonaldJTrumpJr --> @DonaldJTrumpJr @cadillacman1961 That's how my daughter learned when she was that age! At almost 15 now I can't keep her out of the pool LOL
#
# JJ: few --> Why Should Kids Run?: A few scientific findings to ponder...Bone Strength develops the most in pre-teen and e... https://t.co/BW9e4KdKqG
#
# JJ: scientific --> Why Should Kids Run?: A few scientific findings to ponder...Bone Strength develops the most in pre-teen and e... https://t.co/BW9e4KdKqG
#
# JJ: pre-teen --> Why Should Kids Run?: A few scientific findings to ponder...Bone Strength develops the most in pre-teen and e... https://t.co/BW9e4KdKqG
#
# JJ: old --> @RealDonald4Pres how old are you? 7? Or less. Grow up kiddo.
#
# JJR: less --> @RealDonald4Pres how old are you? 7? Or less. Grow up kiddo.
#
# JJ: #Fun --> #Fun Disney Frozen Design a Vinyl Elsa Doll | Fun DIY Crafts for Kids with Amy Jo on DCTC: Disney Frozen Desi... https://t.co/ToSZYuxlgP
#
# JJR: @amandalcormier --> @amandalcormier you are a strong beautiful woman Amanda and I am happy to have seen you grown! (I am still an immature child)
#
# JJ: strong --> @amandalcormier you are a strong beautiful woman Amanda and I am happy to have seen you grown! (I am still an immature child)
#
# JJ: beautiful --> @amandalcormier you are a strong beautiful woman Amanda and I am happy to have seen you grown! (I am still an immature child)
#
# JJ: happy --> @amandalcormier you are a strong beautiful woman Amanda and I am happy to have seen you grown! (I am still an immature child)
#
# JJ: #Liveme --> #Liveme #party #fun #hype #Dabs #EmojiChallenge Crazyy_Mitchell🍪’s #onairnow~ https://t.co/5VlivljjMS https://t.co/XRHnwAWtmB
#
# JJ: there's --> If there's anything retail has taught me it's that white people love going into fitting rooms with their grown ass children.
#
# JJ: retail --> If there's anything retail has taught me it's that white people love going into fitting rooms with their grown ass children.
#
# JJ: white --> If there's anything retail has taught me it's that white people love going into fitting rooms with their grown ass children.
#
# JJ: grown --> If there's anything retail has taught me it's that white people love going into fitting rooms with their grown ass children.
#
# JJ: white --> Only ppl that had fun was the white ppl but it was more blacks then whites so that dj should've thought about us man https://t.co/tGIQcNil5K
#
# JJ: creative --> How to raise kids to be creative thinkers https://t.co/72O7whRr4I
#
# JJ: old --> I just got inspiration from a 9 year old...  https://t.co/ydXBB6Rwns
#
# JJ: oven --> Made homemade chicken fingers and oven sweet potato fries because I'm a child #nevergrowingup #adultingtherightway
#
# JJ: sweet --> Made homemade chicken fingers and oven sweet potato fries because I'm a child #nevergrowingup #adultingtherightway
#
# JJ: " --> "Young children don't need to be taught in order to learn. Explicit instruction can be limiting." @AlisonGopnik https://t.co/c0eTZPRgr3
#
# JJ: fancy --> Going somewhere fun where we can be ourselves I'm not into the fancy stuff I'm a child I wanna have fun  https://t.co/k2f03jfmKZ
#
# JJ: @MichiganDEQ --> @MichiganDEQ DRP Incinerator is an atrocity. How many more days must I tell my child she can't play outside bc of stench?
#
# JJ: many --> @MichiganDEQ DRP Incinerator is an atrocity. How many more days must I tell my child she can't play outside bc of stench?
#
# JJR: more --> @MichiganDEQ DRP Incinerator is an atrocity. How many more days must I tell my child she can't play outside bc of stench?
#
# JJ: outside --> @MichiganDEQ DRP Incinerator is an atrocity. How many more days must I tell my child she can't play outside bc of stench?
#
# JJ: young --> When I was a young boy my father take me into the city to see a marching band. He said ( Son when you grow up would you be the saver (1/2)
#
# JJ: live --> We saw a live outdoor play called Nature: a walking play" at… https://t.co/2yATk8EjZi
#
# JJ: outside --> Sometimes parents of #dyslexia can feel like this- so explore learning outside school! #Art #STEM #History #Music  https://t.co/gzZs39YWYo
#
# JJ: little --> My son Jerry, we just got back from a little firing range time in the back 40
#
# JJ: firing --> My son Jerry, we just got back from a little firing range time in the back 40
#
# JJ: https://t.co/gm15UBQHKg --> RT @VibeMagazine: Ghost's face when he learned his son stole Angela's gun...#PowerTV https://t.co/gm15UBQHKg &lt; lmfaooo
#
# JJR: more --> I think me &amp; my friends have more fun at the kids party than the kids do lol!
#
# JJ: Real --> Child Stars You Never Thought Would Grow Up To Be This Super Attractive, #7 Is A Real Hottie https://t.co/YDuaxdGvSz a
#
# JJ: #PowerTV --> #PowerTV RT @VibeMagazine: Ghost's face when he learned his son stole Angela's gun...#PowerTV https://t.co/35wnrw5Y8R
#
# JJ: You're --> You're very welcome! Creativity and kids are my passions!  I'm lucky enough to find opportunities to have a career with both! @ScharkieChamp
#
# JJ: welcome --> You're very welcome! Creativity and kids are my passions!  I'm lucky enough to find opportunities to have a career with both! @ScharkieChamp
#
# JJ: lucky --> You're very welcome! Creativity and kids are my passions!  I'm lucky enough to find opportunities to have a career with both! @ScharkieChamp

# %% [markdown]
# These seem like dreadful results. Let's try a different NLP engine.

# %% [markdown]
# ## Stanford CoreNLP
#
# Download:
#
# http://nlp.stanford.edu/software/stanford-corenlp-full-2016-10-31.zip
#
# Then unzip. Start up the server from the unzipped directory:
#
# `$ java -mx4g -cp "*" edu.stanford.nlp.pipeline.StanfordCoreNLPServer -port 9000 -timeout 15000`

# %%
from corenlp_pywrap import pywrap
cn = pywrap.CoreNLP(url='http://localhost:9000', annotator_list=["pos"])

# %%
corenlp_results = []

for tweet_body in deduped_tweet_bodies:
    try:
        corenlp_results.append( cn.basic(tweet_body,out_format='json').json() )
    except UnicodeEncodeError:
        corenlp_results.append( {'sentences':[]} )

# %%
# pull out the tokens and tags
corenlp_tagged_tokenized_deduped_tweet_bodies = [ [(token['word'],token['pos']) for sentence in result['sentences'] for token in sentence['tokens']] for result in corenlp_results]

# %%
# print format: "POS: TOKEN --> TWEET TEXT"

for body,tagged_tokens in zip(deduped_tweet_bodies,corenlp_tagged_tokenized_deduped_tweet_bodies):
    for token,tag in tagged_tokens:
        #if tag in pn_tags:
        if tag in adjective_tags:
            print_str = '{}: {} --> {}'.format(tag,token,body)
            print(print_str)
# Out:
# JJR: > --> &gt;&gt;&gt;&gt;&gt;NOTHING THE LIBERAL PARTY HAS PRODUCED HAS CREDIBILITY IN IT, &amp; THEY'RE NOT GOING TO START NOW!!! https://t.co/oH5YfQcFCl
#
# JJR: > --> &gt;&gt;&gt;&gt;&gt;NOTHING THE LIBERAL PARTY HAS PRODUCED HAS CREDIBILITY IN IT, &amp; THEY'RE NOT GOING TO START NOW!!! https://t.co/oH5YfQcFCl
#
# JJR: > --> &gt;&gt;&gt;&gt;&gt;NOTHING THE LIBERAL PARTY HAS PRODUCED HAS CREDIBILITY IN IT, &amp; THEY'RE NOT GOING TO START NOW!!! https://t.co/oH5YfQcFCl
#
# JJR: > --> &gt;&gt;&gt;&gt;&gt;NOTHING THE LIBERAL PARTY HAS PRODUCED HAS CREDIBILITY IN IT, &amp; THEY'RE NOT GOING TO START NOW!!! https://t.co/oH5YfQcFCl
#
# JJR: > --> &gt;&gt;&gt;&gt;&gt;NOTHING THE LIBERAL PARTY HAS PRODUCED HAS CREDIBILITY IN IT, &amp; THEY'RE NOT GOING TO START NOW!!! https://t.co/oH5YfQcFCl
#
# JJ: LIBERAL --> &gt;&gt;&gt;&gt;&gt;NOTHING THE LIBERAL PARTY HAS PRODUCED HAS CREDIBILITY IN IT, &amp; THEY'RE NOT GOING TO START NOW!!! https://t.co/oH5YfQcFCl
#
# JJ: early --> About Trump digest (2/7): I started creating Trump digest playlists in early 2016 to teach my kids about Trump, even though most can't vote
#
# JJS: most --> About Trump digest (2/7): I started creating Trump digest playlists in early 2016 to teach my kids about Trump, even though most can't vote
#
# JJ: fantastic --> And now a fantastic electric storm overhead.  The original and best son et lumiere. Other guests all dining indoors. They must be mad!
#
# JJ: electric --> And now a fantastic electric storm overhead.  The original and best son et lumiere. Other guests all dining indoors. They must be mad!
#
# JJ: original --> And now a fantastic electric storm overhead.  The original and best son et lumiere. Other guests all dining indoors. They must be mad!
#
# JJS: best --> And now a fantastic electric storm overhead.  The original and best son et lumiere. Other guests all dining indoors. They must be mad!
#
# JJ: Other --> And now a fantastic electric storm overhead.  The original and best son et lumiere. Other guests all dining indoors. They must be mad!
#
# JJ: mad --> And now a fantastic electric storm overhead.  The original and best son et lumiere. Other guests all dining indoors. They must be mad!
#
# JJR: > --> Why Young Kids Learn Through Movement ----&gt;https://t.co/YyF7HAL04u via @TheAtlantic https://t.co/RiFHdl2ipy
#
# JJ: @TheAtlantic --> Why Young Kids Learn Through Movement ----&gt;https://t.co/YyF7HAL04u via @TheAtlantic https://t.co/RiFHdl2ipy
#
# JJ: creative --> Love this story by @wrivey about a creative way of leaving notes for your kids. https://t.co/ZlmnLgQm0R
#
# JJR: older --> Some people love growing up, they have always wanted to be older. I have always wanted to be a kid for life
#
# JJ: little --> My little brother is learning how to play guitar and I can listen to this kid all day he's getting so good.
#
# JJ: good --> My little brother is learning how to play guitar and I can listen to this kid all day he's getting so good.
#
#
# JJ: Complete --> #Outdoors #Gifts 2016 Lucky Crew Complete #Scooter Red https://t.co/7ga1fYVXwx #Kids #Toys https://t.co/UCEmmWfDQ4
#
# JJ: good --> @JJWatt Oh my!  This is too good.   Love that kid and the bond y'all have developed.
#
# JJ: sad --> sad how kids stay indoors all the time . I know it's hot but fuck, being inside the house all day is depressing
#
# JJ: hot --> sad how kids stay indoors all the time . I know it's hot but fuck, being inside the house all day is depressing
#
# JJ: alternative --> Fun fact. there's a alternative ending to the speech, that Subaru and Rem literally do runaway together get married, have kids.
#
# JJ: runaway --> Fun fact. there's a alternative ending to the speech, that Subaru and Rem literally do runaway together get married, have kids.
#
# JJ: active --> Let your children enjoy the outdoors while staying active with this monkey-bar outdoor play set. This play set has interlocking connecter...
#
# JJ: monkey-bar --> Let your children enjoy the outdoors while staying active with this monkey-bar outdoor play set. This play set has interlocking connecter...
#
# JJ: outdoor --> Let your children enjoy the outdoors while staying active with this monkey-bar outdoor play set. This play set has interlocking connecter...
#
# JJ: few --> Why Should Kids Run?: A few scientific findings to ponder...Bone Strength develops the most in pre-teen and e... https://t.co/BW9e4KdKqG
#
# JJ: scientific --> Why Should Kids Run?: A few scientific findings to ponder...Bone Strength develops the most in pre-teen and e... https://t.co/BW9e4KdKqG
#
# JJS: most --> Why Should Kids Run?: A few scientific findings to ponder...Bone Strength develops the most in pre-teen and e... https://t.co/BW9e4KdKqG
#
# JJ: pre-teen --> Why Should Kids Run?: A few scientific findings to ponder...Bone Strength develops the most in pre-teen and e... https://t.co/BW9e4KdKqG
#
# JJ: old --> @RealDonald4Pres how old are you? 7? Or less. Grow up kiddo.
#
# JJR: @amandalcormier --> @amandalcormier you are a strong beautiful woman Amanda and I am happy to have seen you grown! (I am still an immature child)
#
# JJ: strong --> @amandalcormier you are a strong beautiful woman Amanda and I am happy to have seen you grown! (I am still an immature child)
#
# JJ: beautiful --> @amandalcormier you are a strong beautiful woman Amanda and I am happy to have seen you grown! (I am still an immature child)
#
# JJ: happy --> @amandalcormier you are a strong beautiful woman Amanda and I am happy to have seen you grown! (I am still an immature child)
#
# JJ: grown --> @amandalcormier you are a strong beautiful woman Amanda and I am happy to have seen you grown! (I am still an immature child)
#
# JJ: immature --> @amandalcormier you are a strong beautiful woman Amanda and I am happy to have seen you grown! (I am still an immature child)
#
# JJ: retail --> If there's anything retail has taught me it's that white people love going into fitting rooms with their grown ass children.
#
# JJ: white --> If there's anything retail has taught me it's that white people love going into fitting rooms with their grown ass children.
#
# JJ: fitting --> If there's anything retail has taught me it's that white people love going into fitting rooms with their grown ass children.
#
# JJ: white --> Only ppl that had fun was the white ppl but it was more blacks then whites so that dj should've thought about us man https://t.co/tGIQcNil5K
#
# JJ: creative --> How to raise kids to be creative thinkers https://t.co/72O7whRr4I
#
# JJ: old --> I just got inspiration from a 9 year old...  https://t.co/ydXBB6Rwns
#
# JJ: sweet --> Made homemade chicken fingers and oven sweet potato fries because I'm a child #nevergrowingup #adultingtherightway
#
# JJ: #nevergrowingup --> Made homemade chicken fingers and oven sweet potato fries because I'm a child #nevergrowingup #adultingtherightway
#
# JJ: Young --> "Young children don't need to be taught in order to learn. Explicit instruction can be limiting." @AlisonGopnik https://t.co/c0eTZPRgr3
#
# JJ: Explicit --> "Young children don't need to be taught in order to learn. Explicit instruction can be limiting." @AlisonGopnik https://t.co/c0eTZPRgr3
#
# JJ: fancy --> Going somewhere fun where we can be ourselves I'm not into the fancy stuff I'm a child I wanna have fun  https://t.co/k2f03jfmKZ
#
# JJ: many --> @MichiganDEQ DRP Incinerator is an atrocity. How many more days must I tell my child she can't play outside bc of stench?
#
# JJR: more --> @MichiganDEQ DRP Incinerator is an atrocity. How many more days must I tell my child she can't play outside bc of stench?
#
# JJ: outside --> @MichiganDEQ DRP Incinerator is an atrocity. How many more days must I tell my child she can't play outside bc of stench?
#
# JJ: young --> When I was a young boy my father take me into the city to see a marching band. He said ( Son when you grow up would you be the saver (1/2)
#
# JJ: welcome --> @MsKathrynRenee @kacto_ @ConstanceWu youre welcome! Thanks for making acting not fun for children everywhere!
#
# JJS: Most --> Justin Timberlake Just Gave the Most Inspiring Speech: "I Hope My Son Watches This One Day" https://t.co/pbJgx73u28
#
# JJ: Inspiring --> Justin Timberlake Just Gave the Most Inspiring Speech: "I Hope My Son Watches This One Day" https://t.co/pbJgx73u28
#
# JJ: outside --> Sometimes parents of #dyslexia can feel like this- so explore learning outside school! #Art #STEM #History #Music  https://t.co/gzZs39YWYo
#
# JJ: #Music --> Sometimes parents of #dyslexia can feel like this- so explore learning outside school! #Art #STEM #History #Music  https://t.co/gzZs39YWYo
#
# JJ: hyped --> @LukeGawne -The kid who hit rock bottom. Died n came back to life inspired and decided to fight to get another try its that time. I'm hyped!
#
# JJ: little --> My son Jerry, we just got back from a little firing range time in the back 40
#
# JJ: back --> My son Jerry, we just got back from a little firing range time in the back 40
#
# JJR: < --> RT @VibeMagazine: Ghost's face when he learned his son stole Angela's gun...#PowerTV https://t.co/gm15UBQHKg &lt; lmfaooo
#
# JJ: Super --> Child Stars You Never Thought Would Grow Up To Be This Super Attractive, #7 Is A Real Hottie https://t.co/YDuaxdGvSz a
#
# JJ: Attractive --> Child Stars You Never Thought Would Grow Up To Be This Super Attractive, #7 Is A Real Hottie https://t.co/YDuaxdGvSz a
#
# JJ: Real --> Child Stars You Never Thought Would Grow Up To Be This Super Attractive, #7 Is A Real Hottie https://t.co/YDuaxdGvSz a
#
# JJ: welcome --> You're very welcome! Creativity and kids are my passions!  I'm lucky enough to find opportunities to have a career with both! @ScharkieChamp
#
# JJ: lucky --> You're very welcome! Creativity and kids are my passions!  I'm lucky enough to find opportunities to have a career with both! @ScharkieChamp
#
# JJ: enough --> You're very welcome! Creativity and kids are my passions!  I'm lucky enough to find opportunities to have a career with both! @ScharkieChamp

# %% [markdown]
# # Conclusions and next steps
#
# For Tweet bodies:
# * NLTK TweetTokenizer is pretty good
# * NLTK default POS tagger is dreadful
# * CoreNLP POS tagger is better than NLTK
#
# Next steps:
#
# * Make more careful accuracy measurements
# * Get a better tokenizer into CoreNLP
# * Look at other POS taggers
# * Compare other tags, such as sentiment
